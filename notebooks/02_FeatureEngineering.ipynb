# %%
import pandas as pd

# %%
selected_data = pd.read_csv("../data/02_Interim/01_SelectedFeutures.csv")

# %%
# Make Target Variable based on the column "W jaki sposób chcesz uczestniczyć w Community?"with the following rules:

# 1 - if the answer is "Chcę uczestniczyć w projekcie data" or "Chcę uczestniczyć w projekcie data i organizować "życie" Community"
# 0 - if the answer is anything else


# Solution below generated by Github Copilot:

selected_data["target"] = selected_data["W jaki sposób chcesz uczestniczyć w Community?"].apply(lambda x: "Tak" if x in ["Chcę uczestniczyć w projekcie data", "Chcę uczestniczyć w projekcie data i organizować 'życie' Community"] else "Nie")

# %%
selected_data.to_csv("../data/03_Processed/02_ProcessedData.csv", index=False)
